# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.20.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: nltk>=3.9 in /opt/anaconda3/lib/python3.14/site-packages (from textblob) (3.10.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.14/site-packages (from nltk>=3.9->textblob) (0.7.1)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.14/site-packages (from nltk>=3.9->textblob) (8.4.1)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.14/site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.14/site-packages (from nltk>=3.9->textblob) (2026.5.9)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.14/site-packages (from nltk>=3.9->textblob) (4.68.2)
# Downloading textblob-0.20.1-py3-none-any.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.0/625.0 kB 5.6 MB/s  0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.20.1

# %%
from textblob import TextBlob

def analyze_sentiment():
    print("--- Real-Time Sentiment Analyzer ---")
    print("Type any sentence to analyze. Type 'exit' to quit.\n")

    while True:
        user_input = input("Enter Text: ")

        if user_input.lower().strip() == "exit":
            print("Exiting Analyzer.")
            break

        if not user_input.strip():
            continue

        # Process text using TextBlob
        blob = TextBlob(user_input)
        polarity = blob.sentiment.polarity  # Range: -1.0 (Negative) to +1.0 (Positive)
        subjectivity = (
            blob.sentiment.subjectivity
        )  # Range: 0.0 (Factual) to 1.0 (Opinion)

        # Interpret results
        if polarity > 0.1:
            sentiment_label = "POSITIVE 🙂"
        elif polarity < -0.1:
            sentiment_label = "NEGATIVE 🙁"
        else:
            sentiment_label = "NEUTRAL 😐"

        print(f" -> Sentiment: {sentiment_label}")
        print(
            f" -> Score: Polarity={polarity:.2f}, Subjectivity={subjectivity:.2f}\n"
        )

if __name__ == "__main__":
    analyze_sentiment()
# Out:
# --- Real-Time Sentiment Analyzer ---
# Type any sentence to analyze. Type 'exit' to quit.
# Enter Text:  something is something till the infinity
#  -> Sentiment: NEUTRAL 😐
#  -> Score: Polarity=0.00, Subjectivity=0.00
# Enter Text:  exit
# Exiting Analyzer.

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp314-cp314-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.19.3 in /opt/anaconda3/lib/python3.14/site-packages (from wordcloud) (2.4.6)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.14/site-packages (from wordcloud) (12.3.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.14/site-packages (from wordcloud) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib->wordcloud) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib->wordcloud) (26.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.14/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.6-cp314-cp314-macosx_11_0_arm64.whl (168 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.6

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.14/site-packages (3.10.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.14/site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.14/site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.14/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.14/site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.14/site-packages (from nltk) (4.68.2)
