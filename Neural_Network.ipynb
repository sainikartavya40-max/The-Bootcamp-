# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /opt/anaconda3/lib/python3.14/site-packages (2.22.0rc0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (1.84.0)
# Requirement already satisfied: keras-nightly>=3.12.0.dev in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (3.16.0.dev2026092404)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (2.4.6)
# Requirement already satisfied: h5py~=3.15.1 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /opt/anaconda3/lib/python3.14/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.14/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.14/site-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/lib/python3.14/site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/lib/python3.14/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.7.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/lib/python3.14/site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.14/site-packages (from keras-nightly>=3.12.0.dev->tensorflow) (15.0.0)
# Requirement already satisfied: namex in /opt/anaconda3/lib/python3.14/site-packages (from keras-nightly>=3.12.0.dev->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /opt/anaconda3/lib/python3.14/site-packages (from keras-nightly>=3.12.0.dev->tensorflow) (0.20.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.14/site-packages (from rich->keras-nightly>=3.12.0.dev->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.14/site-packages (from rich->keras-nightly>=3.12.0.dev->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich->keras-nightly>=3.12.0.dev->tensorflow) (0.1.2)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
# Generating simple synthetic data
import numpy as np
np.random.seed(42)
X = np.linspace(-1, 1, 200)
y = X**2 + np.random.normal(0, 0.1, size=X.shape)  # A simple quadratic function with noise

# %%
# Splitting into training and testing sets
X_train, X_test = X[:150], X[150:]
y_train, y_test = y[:150], y[150:]

# %%
X_train
# Out:
# array([-1.        , -0.98994975, -0.9798995 , -0.96984925, -0.95979899,
#        -0.94974874, -0.93969849, -0.92964824, -0.91959799, -0.90954774,
#        -0.89949749, -0.88944724, -0.87939698, -0.86934673, -0.85929648,
#        -0.84924623, -0.83919598, -0.82914573, -0.81909548, -0.80904523,
#        -0.79899497, -0.78894472, -0.77889447, -0.76884422, -0.75879397,
#        -0.74874372, -0.73869347, -0.72864322, -0.71859296, -0.70854271,
#        -0.69849246, -0.68844221, -0.67839196, -0.66834171, -0.65829146,
#        -0.64824121, -0.63819095, -0.6281407 , -0.61809045, -0.6080402 ,
#        -0.59798995, -0.5879397 , -0.57788945, -0.5678392 , -0.55778894,
#        -0.54773869, -0.53768844, -0.52763819, -0.51758794, -0.50753769,
#        -0.49748744, -0.48743719, -0.47738693, -0.46733668, -0.45728643,
#        -0.44723618, -0.43718593, -0.42713568, -0.41708543, -0.40703518,
#        -0.39698492, -0.38693467, -0.37688442, -0.36683417, -0.35678392,
#        -0.34673367, -0.33668342, -0.32663317, -0.31658291, -0.30653266,
#        -0.29648241, -0.28643216, -0.27638191, -0.26633166, -0.25628141,
#        -0.24623116, -0.2361809 , -0.22613065, -0.2160804 , -0.20603015,
#        -0.1959799 , -0.18592965, -0.1758794 , -0.16582915, -0.15577889,
#        -0.14572864, -0.13567839, -0.12562814, -0.11557789, -0.10552764,
#        -0.09547739, -0.08542714, -0.07537688, -0.06532663, -0.05527638,
#        -0.04522613, -0.03517588, -0.02512563, -0.01507538, -0.00502513,
#         0.00502513,  0.01507538,  0.02512563,  0.03517588,  0.04522613,
#         0.05527638,  0.06532663,  0.07537688,  0.08542714,  0.09547739,
#         0.10552764,  0.11557789,  0.12562814,  0.13567839,  0.14572864,
#         0.15577889,  0.16582915,  0.1758794 ,  0.18592965,  0.1959799 ,
#         0.20603015,  0.2160804 ,  0.22613065,  0.2361809 ,  0.24623116,
#         0.25628141,  0.26633166,  0.27638191,  0.28643216,  0.29648241,
#         0.30653266,  0.31658291,  0.32663317,  0.33668342,  0.34673367,
#         0.35678392,  0.36683417,  0.37688442,  0.38693467,  0.39698492,
#         0.40703518,  0.41708543,  0.42713568,  0.43718593,  0.44723618,
#         0.45728643,  0.46733668,  0.47738693,  0.48743719,  0.49748744])

# %%
# Building a simple neural network model
from tensorflow import keras
model = keras.Sequential([
    keras.layers.Dense(10, activation='relu', input_shape=(1,)),  # Hidden layer with 10 neurons
    keras.layers.Dense(1)  # Output layer
])

# %%
# Compiling the model
model.compile(optimizer='adam', loss='mse')

# %%
# Training the model
history = model.fit(X_train, y_train, epochs=100, verbose=0)  # 100 epochs

# %%
# Making predictions
import numpy as np
X_test = np.array(X_test).reshape(-1, 1)  # Ensure consistent shape
y_pred = model.predict(X_test, verbose=0)  # Disable unnecessary verbosity

# %%
# Plotting results
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
plt.scatter(X_train, y_train, color='blue', label='Training Data')
plt.scatter(X_test, y_test, color='red', label='Testing Data')
plt.plot(X_test, y_pred, color='black', linewidth=2, label='Predictions')
plt.xlabel('Input X')
plt.ylabel('Output y')
plt.title('Simple Neural Network Regression')
plt.legend()
plt.show()

# %%
# Explanation of the model
print("\nDeep Learning Model Explanation:")
print("1. We created a simple neural network with one hidden layer (10 neurons) and ReLU activation.")
print("2. The model was trained on synthetic quadratic data.")
print("3. Adam optimizer was used for efficient learning.")
print("4. After training, the model is learning the pattern in the data.")
